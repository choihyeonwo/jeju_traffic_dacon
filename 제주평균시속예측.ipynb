# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def csv_to_parquet(csv_path, save_name):
    df = pd.read_csv(csv_path)
    df.to_parquet(f'./{save_name}.parquet')
    del df
    gc.collect()
    print(save_name, 'Done.')

# %%
path = 'train.csv'
jeju_traffic = pd.read_csv(path)
jeju_traffic
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4701212  TRAIN_4701212   20211104           목         16            0
# 4701213  TRAIN_4701213   20220331           목          2            0
# 4701214  TRAIN_4701214   20220613           월         22            0
# 4701215  TRAIN_4701215   20211020           수          2            0
# 4701216  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
# filt = df['수학'] < 80 
# df[filt]
# df.drop(index = df[filt].index)

# %%
temp = jeju_traffic.loc[jeju_traffic['target']==113].index
temp
# Out:
# Int64Index([3841974, 4386692], dtype='int64')

# %%
jeju_traffic.drop(index = temp, inplace = True)
jeju_traffic= jeju_traffic.reset_index(drop = True)
jeju_traffic
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4701210  TRAIN_4701212   20211104           목         16            0
# 4701211  TRAIN_4701213   20220331           목          2            0
# 4701212  TRAIN_4701214   20220613           월         22            0
# 4701213  TRAIN_4701215   20211020           수          2            0
# 4701214  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
print(jeju_traffic['base_date'].min())
print(jeju_traffic['base_date'].max())
# Out:
# 20210901
# 20220731

# %%
jeju_traffic1 = jeju_traffic.copy()

# %%
# 날짜 데이터 나누기

def date_function(row):
    result = str(row)
    return result[:4] + '-' + result[4:6] + '-' + result[6:]
    

jeju_traffic1['base_date(date_time)'] = jeju_traffic1['base_date'].apply(date_function)
jeju_traffic1
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4701210  TRAIN_4701212   20211104           목         16            0
# 4701211  TRAIN_4701213   20220331           목          2            0
# 4701212  TRAIN_4701214   20220613           월         22            0
# 4701213  TRAIN_4701215   20211020           수          2            0
# 4701214  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
jeju_traffic1['month'] = pd.to_datetime(jeju_traffic1['base_date(date_time)']).dt.month

# jeju_traffic1

# %%
tmp = jeju_traffic1.groupby('month', as_index = False)['target'].mean()

jeju_traffic1['성수기'] = 0

jeju_traffic1.loc[jeju_traffic1['month'] == 7 , '성수기'] = 1
jeju_traffic1
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4701210  TRAIN_4701212   20211104           목         16            0
# 4701211  TRAIN_4701213   20220331           목          2            0
# 4701212  TRAIN_4701214   20220613           월         22            0
# 4701213  TRAIN_4701215   20211020           수          2            0
# 4701214  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
tmp = pd.DataFrame(jeju_traffic1.loc[jeju_traffic1['multi_linked'] == 1, 'multi_linked'])
tmp
# jeju_traffic1 = jeju_traffic1.drop()
# df.drop(index = df[filt].index)
jeju_traffic1.drop(index = tmp.index, inplace = True)
jeju_traffic1
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4701210  TRAIN_4701212   20211104           목         16            0
# 4701211  TRAIN_4701213   20220331           목          2            0
# 4701212  TRAIN_4701214   20220613           월         22            0
# 4701213  TRAIN_4701215   20211020           수          2            0
# 4701214  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
jeju_traffic1.reset_index(drop = True, inplace = True)
jeju_traffic1
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4698971  TRAIN_4701212   20211104           목         16            0
# 4698972  TRAIN_4701213   20220331           목          2            0
# 4698973  TRAIN_4701214   20220613           월         22            0
# 4698974  TRAIN_4701215   20211020           수          2            0
# 4698975  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
#test

path = 'test.csv'
test = pd.read_csv(path)
test
# Out:
#                  id  base_date day_of_week  base_hour  lane_count  \
# 0       TEST_000000   20220825           목         17           3
# 1       TEST_000001   20220809           화         12           2
# 2       TEST_000002   20220805           금          2           1
# 3       TEST_000003   20220818           목         23           3
# 4       TEST_000004   20220810           수         17           3
# ...             ...        ...         ...        ...         ...
# 291236  TEST_291236   20220827           토          5           1
# 291237  TEST_291237   20220819           금         20           2
# 291238  TEST_291238   20220805           금         11           1
# 291239  TEST_291239   20220812           금          7           2
# 291240  TEST_291240   20220812           금         10           3
#
#         road_rating  road_name  multi_linked  connect_code  \
# 0               107        연삼로             0             0
# ...

# %%
# 날짜 데이터 나누기

def date_function(row):
    result = str(row)
    return result[:4] + '-' + result[4:6] + '-' + result[6:]

test['성수기'] = test['base_date'].apply(date_function)

# %%
test['month'] = pd.to_datetime(test['성수기']).dt.month
test
# Out:
#                  id  base_date day_of_week  base_hour  lane_count  \
# 0       TEST_000000   20220825           목         17           3
# 1       TEST_000001   20220809           화         12           2
# 2       TEST_000002   20220805           금          2           1
# 3       TEST_000003   20220818           목         23           3
# 4       TEST_000004   20220810           수         17           3
# ...             ...        ...         ...        ...         ...
# 291236  TEST_291236   20220827           토          5           1
# 291237  TEST_291237   20220819           금         20           2
# 291238  TEST_291238   20220805           금         11           1
# 291239  TEST_291239   20220812           금          7           2
# 291240  TEST_291240   20220812           금         10           3
#
#         road_rating  road_name  multi_linked  connect_code  \
# 0               107        연삼로             0             0
# ...

# %%
test['성수기'] == 0
test.loc[test['month'] == 8 , '성수기'] = 1
test
# Out:
#                  id  base_date day_of_week  base_hour  lane_count  \
# 0       TEST_000000   20220825           목         17           3
# 1       TEST_000001   20220809           화         12           2
# 2       TEST_000002   20220805           금          2           1
# 3       TEST_000003   20220818           목         23           3
# 4       TEST_000004   20220810           수         17           3
# ...             ...        ...         ...        ...         ...
# 291236  TEST_291236   20220827           토          5           1
# 291237  TEST_291237   20220819           금         20           2
# 291238  TEST_291238   20220805           금         11           1
# 291239  TEST_291239   20220812           금          7           2
# 291240  TEST_291240   20220812           금         10           3
#
#         road_rating  road_name  multi_linked  connect_code  \
# 0               107        연삼로             0             0
# ...

# %%
# tmp = pd.DataFrame(test.loc[test['multi_linked'] == 1, 'multi_linked'])
# tmp
# jeju_traffic1 = jeju_traffic1.drop()
# df.drop(index = df[filt].index)
# test.drop(index = tmp.index, inplace = True)
# test

# %%
path = '전국렌터카업체정보표준데이터.csv'
car = pd.read_csv(path, encoding = 'cp949')
car.head()
# Out:
#            업체명 사업장구분                         소재지도로명주소                 소재지지번주소  \
# 0       ㈜디디렌트카  주사업장        서울특별시 노원구 동일로250길 69(상계동)                     NaN
# 1     인천공항렌트카㈜  주사업장  서울특별시 노원구 동일로 178길 10 201호(공릉동)                     NaN
# 2     (주)한지렌터카   영업소             경상북도 영덕군 영덕읍 영덕로 273  경상북도 영덕군 영덕읍 화수리 669-5
# 3  (주)새한글로벌렌터카   영업소             경상북도 영덕군 영덕읍 영덕로 163    경상북도 영덕군 영덕읍 우곡리 217
# 4   (주)진해군항렌터카   영업소            경상북도 영덕군 영덕읍 서원길 27-1  경상북도 영덕군 영덕읍 우곡리 401-7
#
#           위도          경도                        차고지도로명주소  \
# 0  37.682856  127.059089  서울특별시 노원구 상계동 1227, 1229, 1230
# 1  37.621287  127.075141              서울특별시 양천구 목동서로 225
# 2  36.418672  129.373201            경상북도 영덕군 영덕읍 영덕로 273
# 3  36.409014  129.374910            경상북도 영덕군 강구면 하저길 139
# 4  36.405374  129.376321        경상북도 영덕군 강구면 동해대로 4404-4
#
#                    차고지지번주소  보유차고지수용능력  자동차총보유대수  ...  주말운영종료시각  공휴일운영시작시각  \
# 0                      NaN        NaN        60  ...       NaN        NaN
# ...

# %%
path = '전국렌터카업체정보표준데이터.csv'
car = pd.read_csv(path, encoding = 'cp949')
car.head()


car = car.loc[car['제공기관명'] == '제주특별자치도']
car = car[['자동차총보유대수']].reset_index(drop = True)
jeju_traffic1 = pd.concat([jeju_traffic1, car], join = 'outer', axis = 1 )

jeju_traffic_mean = jeju_traffic1['자동차총보유대수'].mean()
jeju_traffic1['자동차총보유대수'].fillna(jeju_traffic_mean, inplace = True)

# %%
car.shape
# Out:
# (113, 1)

# %%
car.isna().sum()
# Out:
# 자동차총보유대수    0
# dtype: int64

# %%
car = car[['자동차총보유대수']].reset_index(drop = True)

# %%
car
# Out:
#      자동차총보유대수
# 0         100
# 1         100
# 2         105
# 3         335
# 4         100
# ..        ...
# 108       100
# 109       294
# 110       108
# 111       173
# 112       227
#
# [113 rows x 1 columns]

# %%
jeju_traffic1 = pd.concat([jeju_traffic1, car], join = 'outer', axis = 1 )
jeju_traffic1.head(15)
# Out:
#                id  base_date day_of_week  base_hour  road_in_use  lane_count  \
# 0   TRAIN_0000000   20220623           목         17            0           1
# 1   TRAIN_0000001   20220728           목         21            0           2
# 2   TRAIN_0000002   20211010           일          7            0           2
# 3   TRAIN_0000003   20220311           금         13            0           2
# 4   TRAIN_0000004   20211005           화          8            0           2
# 5   TRAIN_0000005   20210913           월          7            0           2
# 6   TRAIN_0000006   20220106           목          0            0           2
# 7   TRAIN_0000007   20211213           월         16            0           2
# 8   TRAIN_0000008   20211004           월         15            0           2
# 9   TRAIN_0000009   20211208           수          2            0           1
# 10  TRAIN_0000010   20220623           목         11            0           1
# ...

# %%
jeju_traffic_mean = jeju_traffic1['자동차총보유대수'].mean()
jeju_traffic_mean
# Out:
# 자동차총보유대수    263.761062
# 자동차총보유대수    263.761062
# dtype: float64

# %%
jeju_traffic1['자동차총보유대수'].fillna(jeju_traffic_mean, inplace = True)
jeju_traffic1
# Out:
#                     id  base_date day_of_week  base_hour  road_in_use  \
# 0        TRAIN_0000000   20220623           목         17            0
# 1        TRAIN_0000001   20220728           목         21            0
# 2        TRAIN_0000002   20211010           일          7            0
# 3        TRAIN_0000003   20220311           금         13            0
# 4        TRAIN_0000004   20211005           화          8            0
# ...                ...        ...         ...        ...          ...
# 4698971  TRAIN_4701212   20211104           목         16            0
# 4698972  TRAIN_4701213   20220331           목          2            0
# 4698973  TRAIN_4701214   20220613           월         22            0
# 4698974  TRAIN_4701215   20211020           수          2            0
# 4698975  TRAIN_4701216   20211019           화          6            0
#
#          lane_count  road_rating  road_name  multi_linked  connect_code  ...  \
# ...

# %%
del_c = ['id','base_date','road_name', 'start_node_name', 'end_node_name','vehicle_restricted','base_date(date_time)','month']

jeju_traffic1 = jeju_traffic1.drop(columns = del_c , axis = 1)
jeju_traffic1
# Out:
#         day_of_week  base_hour  road_in_use  lane_count  road_rating  \
# 0                 목         17            0           1          106
# 1                 목         21            0           2          103
# 2                 일          7            0           2          103
# 3                 금         13            0           2          107
# 4                 화          8            0           2          103
# ...             ...        ...          ...         ...          ...
# 4698971           목         16            0           1          107
# 4698972           목          2            0           2          107
# 4698973           월         22            0           2          103
# 4698974           수          2            0           2          103
# 4698975           화          6            0           2          107
#
#          multi_linked  connect_code  maximum_speed_limit  weight_restricted  \
# ...

# %%
del_c = ['id','base_date','road_name', 'start_node_name', 'end_node_name','vehicle_restricted', 'month']
test = test.drop(columns = del_c, axis = 1)
test.head()
# Out:
#   day_of_week  base_hour  lane_count  road_rating  multi_linked  connect_code  \
# 0           목         17           3          107             0             0
# 1           화         12           2          103             0             0
# 2           금          2           1          103             0             0
# 3           목         23           3          103             0             0
# 4           수         17           3          106             0             0
#
#    maximum_speed_limit  weight_restricted  height_restricted  road_type  \
# 0                 70.0                0.0                0.0          0
# 1                 70.0                0.0                0.0          3
# 2                 60.0                0.0                0.0          0
# 3                 70.0                0.0                0.0          0
# 4                 70.0                0.0                0.0          0
#
# ...

# %%
test = pd.concat([test, car], join = 'outer', axis = 1 )
test
# Out:
#        day_of_week  base_hour  lane_count  road_rating  multi_linked  \
# 0                목         17           3          107             0
# 1                화         12           2          103             0
# 2                금          2           1          103             0
# 3                목         23           3          103             0
# 4                수         17           3          106             0
# ...            ...        ...         ...          ...           ...
# 291236           토          5           1          103             0
# 291237           금         20           2          103             0
# 291238           금         11           1          107             0
# 291239           금          7           2          107             0
# 291240           금         10           3          106             0
#
#         connect_code  maximum_speed_limit  weight_restricted  \
# 0                  0                 70.0                0.0
# ...

# %%
test.reset_index(drop =  True, inplace= True)
test
# Out:
#        day_of_week  base_hour  lane_count  road_rating  multi_linked  \
# 0                목         17           3          107             0
# 1                화         12           2          103             0
# 2                금          2           1          103             0
# 3                목         23           3          103             0
# 4                수         17           3          106             0
# ...            ...        ...         ...          ...           ...
# 291236           토          5           1          103             0
# 291237           금         20           2          103             0
# 291238           금         11           1          107             0
# 291239           금          7           2          107             0
# 291240           금         10           3          106             0
#
#         connect_code  maximum_speed_limit  weight_restricted  \
# 0                  0                 70.0                0.0
# ...

# %%
jeju_traffic_mean = test['자동차총보유대수'].mean()
test['자동차총보유대수'].fillna(jeju_traffic_mean, inplace = True)
test
# Out:
#        day_of_week  base_hour  lane_count  road_rating  multi_linked  \
# 0                목         17           3          107             0
# 1                화         12           2          103             0
# 2                금          2           1          103             0
# 3                목         23           3          103             0
# 4                수         17           3          106             0
# ...            ...        ...         ...          ...           ...
# 291236           토          5           1          103             0
# 291237           금         20           2          103             0
# 291238           금         11           1          107             0
# 291239           금          7           2          107             0
# 291240           금         10           3          106             0
#
#         connect_code  maximum_speed_limit  weight_restricted  \
# 0                  0                 70.0                0.0
# ...

# %%
## laeb

from sklearn.preprocessing import LabelEncoder

str_col = ['day_of_week','start_turn_restricted','end_turn_restricted','성수기']
for i in str_col:
    le = LabelEncoder()
    le=le.fit(jeju_traffic1[i])
    jeju_traffic1[i]=le.transform(jeju_traffic1[i])
    
    for label in np.unique(test[i]):
        if label not in le.classes_: 
            le.classes_ = np.append(le.classes_, label)
    test[i]=le.transform(test[i])
# Out:
# <ipython-input-39-42e05b5adf09>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jeju_traffic1[i]=le.transform(jeju_traffic1[i])

# %%
jeju_traffic1
# Out:
#          day_of_week  base_hour  road_in_use  lane_count  road_rating  \
# 0                  1         17            0           1          106
# 1                  1         21            0           2          103
# 2                  4          7            0           2          103
# 3                  0         13            0           2          107
# 4                  6          8            0           2          103
# ...              ...        ...          ...         ...          ...
# 4698971            1         16            0           1          107
# 4698972            1          2            0           2          107
# 4698973            3         22            0           2          103
# 4698974            2          2            0           2          103
# 4698975            6          6            0           2          107
#
#          multi_linked  connect_code  maximum_speed_limit  weight_restricted  \
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import VotingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
# x ,y 로 나누기 

target = 'target'

x = jeju_traffic1.drop(target, axis = 1)
y = jeju_traffic1[target]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (3289283, 20)
# (1409693, 20)

# %%
model_xgb = XGBRegressor(random_state = 42)
model_light = LGBMRegressor(random_state = 42)
model_voting = VotingRegressor(estimators=[('light', model_light), ('xgb', model_xgb)])

# %%
#보팅
model_voting.fit(x_train, y_train)

y_pred = model_voting.predict(test)

# %%
#LIGHTGBM 
model_light.fit(x_train, y_train)

y_pred_light = model_light.predict(test)

# %%
model_xgb.fit(x_train, y_train)

y_pred_xgb = model_xgb.predict(test)

sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['target'] = y_pred_xgb
sample_submission.to_csv('xgb1.csv', index = False)

# %%
sample_submission

# %%
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission

# %%
sample_submission['target'] = y_pred
sample_submission

# %%
sample_submission.to_csv('voting.csv', index = False)

# %%
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['target'] = y_pred_light
sample_submission
sample_submission.to_csv('light_regressor.csv')
# Out:
#                  id     target
# 0       TEST_000000  27.278014
# 1       TEST_000001  43.697730
# 2       TEST_000002  59.563810
# 3       TEST_000003  36.205646
# 4       TEST_000004  37.487270
# ...             ...        ...
# 291236  TEST_291236  48.066928
# 291237  TEST_291237  53.020958
# 291238  TEST_291238  21.428031
# 291239  TEST_291239  26.906003
# 291240  TEST_291240  40.688768
#
# [291241 rows x 2 columns]

# %%
print(pred)

# %%
print(x.shape)
print(y.shape)
# Out:
# (4701217, 18)
# (4701217,)

# %%
model_DT = DecisionTreeRegressor(random_state=42)

cv_score = cross_val_score(model_DT, x_train, y_train, cv = 5)

print(cv_score)
print(cv_score.mean())
# Out:
# [0.89684304 0.89754231 0.89768524 0.89769453 0.89738163]
# 0.8974293520407437

# %%
model_DT = DecisionTreeRegressor(random_state=42)

model_DT.fit(x_train, y_train)

y_pred_DT = model_DT.predict(test)

# %%
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission
# Out:
#                  id  target
# 0       TEST_000000       0
# 1       TEST_000001       0
# 2       TEST_000002       0
# 3       TEST_000003       0
# 4       TEST_000004       0
# ...             ...     ...
# 291236  TEST_291236       0
# 291237  TEST_291237       0
# 291238  TEST_291238       0
# 291239  TEST_291239       0
# 291240  TEST_291240       0
#
# [291241 rows x 2 columns]

# %%
sample_submission[target] = y_pred_DT
sample_submission.to_csv('Decision_Tree.csv')

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)
